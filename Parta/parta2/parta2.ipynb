# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/parta2.txt')
df.columns = ['Monthly_period', 'Average Transactions made every month']

# %%
df.head()
# Out:
#   Monthly_period  Average Transactions made every month
# 0        06/2017                           5.678772e+19
# 1        12/2015                           2.676410e+19
# 2        06/2018                           2.808523e+18
# 3        08/2015                           4.805212e+20
# 4        08/2018                           2.398951e+18

# %%
plt.figure(figsize = (30,10))
plt.xticks(rotation=90)
plt.xlabel('period')
plt.ylabel('Average Transactions')
x=df['Monthly_period']
y=df['Average Transactions made every month']
plt.bar(x,y,color='blue')
# Out:
# <BarContainer object of 41 artists>
